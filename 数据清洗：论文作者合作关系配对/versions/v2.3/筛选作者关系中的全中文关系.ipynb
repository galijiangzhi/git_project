# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../../../../def')

# %%
import str_process

# %%
authors_cp_name = pd.read_excel('./excel/作者关系2.0.xlsx')

# %%
authors_cp_id = pd.read_excel('./excel/作者编号配对2.0.xlsx')

# %%
for i in range (len(authors_cp_name)):
    for j in range(2):
        authors_cp_name.iloc[i,j]=str_process.chinese_all(authors_cp_name.iloc[i,j])

# %%
authors_cp_plus = authors_cp_name

# %%
authors_cp_plus.insert(loc=2,column='result',value=(''))

# %%
authors_cp_plus
# Out:
#       author_a author_b result organization
# 0         True     True            中国科学技术大学
# 1         True     True            中国科学技术大学
# 2         True     True            中国科学技术大学
# 3         True     True            中国科学技术大学
# 4         True     True            中国科学技术大学
# 5         True     True                福州大学
# 6         True     True                福州大学
# 7         True     True                福州大学
# 8         True     True                福州大学
# 9         True     True              西安交通大学
# 10        True     True              西安交通大学
# 11        True     True              西安交通大学
# 12        True     True              西安交通大学
# 13        True     True              沈阳化工大学
# 14        True     True              沈阳化工大学
# 15        True     True              沈阳化工大学
# 16        True     True                暨南大学
# 17        True     True                天津大学
# 18        True     True                天津大学
# 19        True     True                天津大学
# ...

# %%
authors_cp_plus['resule']=authors_cp_plus['author_a']*authors_cp_plus['author_b']

# %%
authors_cp_plus
# Out:
#       author_a author_b result organization resule
# 0         True     True            中国科学技术大学      1
# 1         True     True            中国科学技术大学      1
# 2         True     True            中国科学技术大学      1
# 3         True     True            中国科学技术大学      1
# 4         True     True            中国科学技术大学      1
# 5         True     True                福州大学      1
# 6         True     True                福州大学      1
# 7         True     True                福州大学      1
# 8         True     True                福州大学      1
# 9         True     True              西安交通大学      1
# 10        True     True              西安交通大学      1
# 11        True     True              西安交通大学      1
# 12        True     True              西安交通大学      1
# 13        True     True              沈阳化工大学      1
# 14        True     True              沈阳化工大学      1
# 15        True     True              沈阳化工大学      1
# 16        True     True                暨南大学      1
# ...

# %%
list = authors_cp_plus['resule']==1

# %%
authors_cp_plus.loc[list]
# Out:
#       author_a author_b result     organization resule
# 0         True     True                中国科学技术大学      1
# 1         True     True                中国科学技术大学      1
# 2         True     True                中国科学技术大学      1
# 3         True     True                中国科学技术大学      1
# 4         True     True                中国科学技术大学      1
# 5         True     True                    福州大学      1
# 6         True     True                    福州大学      1
# 7         True     True                    福州大学      1
# 8         True     True                    福州大学      1
# 9         True     True                  西安交通大学      1
# 10        True     True                  西安交通大学      1
# 11        True     True                  西安交通大学      1
# 12        True     True                  西安交通大学      1
# 13        True     True                  沈阳化工大学      1
# 14        True     True                  沈阳化工大学      1
# 15        True     True                  沈阳化工大学      1
# ...

# %%
authors_cp_chinese = pd.read_excel('./excel/作者关系2.0.xlsx')

# %%
authors_cp_chinese_list=authors_cp_chinese.loc[list]

# %%
authors_cp_id_list=authors_cp_id.loc[list]

# %%
authors_cp_chinese_list.reset_index(inplace=True)

# %%
authors_cp_id_list.reset_index(inplace=True)

# %%
authors_cp_chinese_list.drop('index',axis=1,inplace=True)
# Out:
# /home/baizhen/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
authors_cp_id_list.drop('index',axis=1,inplace=True)
# Out:
# /home/baizhen/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
authors_cp_id_list.to_excel('./excel/作者关系全中文关系-编号版.xlsx')

# %%
authors_cp_chinese_list.to_excel('./excel/作者关系全中文关系-姓名版.xlsx')
