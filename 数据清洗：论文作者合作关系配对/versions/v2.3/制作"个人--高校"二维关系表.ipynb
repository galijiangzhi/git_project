# %%
import pandas as pd
import numpy as np

# %%
authors=pd.read_excel('./excel/作者编号列表2.0.xlsx')
organization=pd.read_excel('./excel/大学编号列表.xlsx')

# %%
df = pd.DataFrame(data=None,index=authors.loc[:,'authors'],columns=organization.loc[:,'organization'])

# %%
len(df)
# Out:
# 9709

# %%
df.iloc[0,0]='00'

# %%
authors.loc[0,'organization']
# Out:
# '中国科学技术大学'

# %%
organization.loc[0,'organization']
# Out:
# '中国科学技术大学'

# %%
for i in range(len(df)):
    author=authors.loc[i,'organization']
    df.iloc[i]=(author==df.columns)

# %%
df
# Out:
# organization           中国科学技术大学   福州大学  西安交通大学  沈阳化工大学   暨南大学   天津大学   武汉大学  \
# authors
# 邹紫盛                        True  False   False   False  False  False  False
# 丛爽                         True  False   False   False  False  False  False
# 王大欣                        True  False   False   False  False  False  False
# 陈鼎                         True  False   False   False  False  False  False
# 尚伟伟                        True  False   False   False  False  False  False
# 邹阳                        False   True   False   False  False  False  False
# 李安娜                       False   True   False   False  False  False  False
# 蔡金锭                       False   True   False   False  False  False  False
# 甘露                        False   True   False   False  False  False  False
# 邹涛                        False  False    True   False  False  False  False
# 王丁丁                       False  False    True   False  False  False  False
# ...

# %%
df_int=df.astype('int')

# %%
df_int.to_excel('./excel/’个人-高校‘二维关系表_数字版.xlsx')

# %%
type(df.iloc[:,1])
# Out:
# pandas.core.series.Series

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df.columns[0]
# Out:
# '中国科学技术大学'
